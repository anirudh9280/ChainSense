# %% [markdown]
# ## 1. Setup
#
# Inspecting raw block, transactions.

# %%
import os, json, time, requests, pandas as pd
from web3 import Web3
from dotenv import load_dotenv

load_dotenv()
URL = f"https://eth-mainnet.g.alchemy.com/v2/{os.getenv('ALCHEMY_KEY')}"

# RPC 2.0, jsonrpc.org/specification
def rpc(method, params):
    r = requests.post(URL, json={"jsonrpc":"2.0","id":1,"method":method,"params":params})
    j = r.json()
    if "error" in j:
        raise RuntimeError(j["error"])
    return j["result"]
# Out:
# GWbCaN4jeRa-99GIoWp6S

# %% [markdown]
# ### 1-1. Raw Block

# %%
from IPython.display import JSON

# https://ethereum.org/developers/docs/apis/json-rpc/#eth-blocknumber
# https://ethereum.org/developers/docs/apis/json-rpc/#eth-getblockbynumber
latest = rpc("eth_blockNumber", [])                # eth_blockNumber returns hex string
block = rpc("eth_getBlockByNumber", [latest, True])    # eth-getblockbynumber 

# print(json.dumps(block, indent=2)[:3000])
# display(JSON(block))
# Out:
# status: 200
# headers: {'date': 'Sat, 16 May 2026 05:14:09 GMT', 'content-type': 'application/json', 'content-length': '45', 'x-envoy-upstream-service-time': '3', 'server': 'istio-envoy', 'x-alchemy-response-code': '200', 'x-alchemy-trace-id': 'acca4a18-80dd-4011-b02e-24d732e8da96'}
# body: '{"jsonrpc":"2.0","id":1,"result":"0x17f149d"}'
# status: 200
# headers: {'date': 'Sat, 16 May 2026 05:14:09 GMT', 'content-type': 'application/json', 'content-encoding': 'gzip', 'x-envoy-upstream-service-time': '19', 'server': 'istio-envoy', 'x-alchemy-response-code': '200', 'x-alchemy-trace-id': '75654add-ab87-444a-84c9-dab9c485c9f4', 'transfer-encoding': 'chunked'}
# body: '{"jsonrpc":"2.0","id":1,"result":{"hash":"0xf0fcf5dc5cc14a8ec3fe0e85c6bc61e08e4fb4e6a30f18f13efc3e2acdcb60a3","parentHash":"0xacbfe8915057af6192808529f50bad2440133f887da09d07fa48d8a04a902ee6","sha3Uncles":"0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347","miner":"0x42de17266cb550f384842c911b8a6223d286d1eb","stateRoot":"0xe9796fdfc27ca2df2b147faac377cf9ff3c8ae2712eb72967fb069a294abe2ac","transactionsRoot":"0x1bf6ca6cea79028ca954ac64692345ce4dcdfeadf6a3cabe9b9aac3907083c03","rec'

# %%
latest = rpc("eth_blockNumber", [])
block = rpc("eth_getBlockByNumber", [latest, True])
print(json.dumps(block, indent=2)[:3000])
# Out:
# status: 200
# headers: {'date': 'Sat, 16 May 2026 05:08:22 GMT', 'content-type': 'application/json', 'content-length': '45', 'x-envoy-upstream-service-time': '11', 'server': 'istio-envoy', 'x-alchemy-response-code': '200', 'x-alchemy-trace-id': '7b3e5b10-fdbe-441d-a095-7dc57caf600a'}
# body: '{"jsonrpc":"2.0","id":1,"result":"0x17f1480"}'
# status: 200
# headers: {'date': 'Sat, 16 May 2026 05:08:22 GMT', 'content-type': 'application/json', 'content-encoding': 'gzip', 'x-envoy-upstream-service-time': '26', 'server': 'istio-envoy', 'x-alchemy-response-code': '200', 'x-alchemy-trace-id': '63678a4f-6cac-4f19-b5e8-c9ba67e48d6a', 'transfer-encoding': 'chunked'}
# body: '{"jsonrpc":"2.0","id":1,"result":{"hash":"0x9d447d8ab13d96338b31712b6f8730f8559ffc5ebda7b847ffad7951966c59be","parentHash":"0xb42c9ac064360ae27c26c0a3164804a5cda3a0a8a5ee935c810e1fafe3b71826","sha3Uncles":"0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347","miner":"0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97","stateRoot":"0x5c65829ce3085c0c0cb13c90d3ce11a0b280058c15e55925c6b7782a43e29e78","transactionsRoot":"0xe67d6a58ebe65bc0f52fd1ba78398857bf6db2a4e1d508070a9d31dfb46742fe","rec'
# {
#   "hash": "0x9d447d8ab13d96338b31712b6f8730f8559ffc5ebda7b847ffad7951966c59be",
#   "parentHash": "0xb42c9ac064360ae27c26c0a3164804a5cda3a0a8a5ee935c810e1fafe3b71826",
#   "sha3Uncles": "0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347",
#   "miner": "0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97",
#   "stateRoot": "0x5c65829ce3085c0c0cb13c90d3ce11a0b280058c15e55925c6b7782a43e29e78",
#   "transactionsRoot": "0xe67d6a58ebe65bc0f52fd1ba78398857bf6db2a4e1d508070a9d31dfb46742fe",
#   "receiptsRoot": "0xbb7cd2c0deaca172404f6fd5b2984fe25fa05c633ca09129e6e1ac6ace5ea4ff",
#   "logsBloom": "...",
#   "difficulty": "0x0",
#   "number": "0x17f1480",
#   "gasLimit": "0x3938700",
#   "gasUsed": "0x12191cf",
#   "timestamp": "0x6a07fbbb",
#   "extraData": "0x546974616e2028746974616e6275696c6465722e78797a29",
#   "mixHash": "0x2b199be8fb9b099714ff7ab7eb9e7864b797505ed623f67a038c77760c150c53",
#   "nonce": "0x0000000000000000",
#   "baseFeePerGas": "0x6a7684c",
#   "withdrawalsRoot": "0x88cbb1882be235cdb06ebeac999e7427ccabcdcbb9006d2a56451f67b9f85e58",
#   "blobGasUsed": "0xc0000",
#   "excessBlobGas": "0xad17069",
#   "parentBeaconBlockRoot": "0xa6d5510dcb3d6c936fe8df03027e8a1e3b72b109cb6d4de9f446001408ce95d0",
#   "requestsHash": "0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855",
#   "size": "0x1e5d6",
#   "uncles": [],
#   "transactions": [
#     {
#       "type": "0x2",
#       "chainId": "0x1",
#       "nonce": "0x84f0",
#       "gas": "0x88b8",
#       "maxFeePerGas": "0x2b2ad87c",
#       "maxPriorityFeePerGas": "0x1e6dcdf1",
#       "to": "0x681e908b8ab57c49c74d770f369754ccc3e1ae09",
#       "value": "0x0",
#       "accessList": [],
#       "input": "0x6a07fbbd872f75f64a005e79ec104d0005f57383090000000000fafa00019e2f2f533600",
#       "r": "0x8993ddc89a3e65703fcd9d5c382218a18827e21e7ae78c1385e83ceee485667",
#       "s": "0x369639caca666aedc74c61a0c8988eb137cfcfab411f157c187755681ead58f3",
#       "yParity": "0x1",
#       "v": "0x1",
#       "hash": "0x962bf773e1a43d17fe938f9852c334c2982b488750c6c3999de28e00924eb356",
#       "blockHash": "0x9d447d8ab13d96338b31712b6f8730f8559ffc5ebda7b847ffad7951966c59be",
#       "blockNumber": "0x17f1480",
#       "transactionIndex": "0x0",
#       "from": "0x8769f5d3505a64be882f4071a8e4bf473179933a",
#       "gasPrice": "0x2515363d"
#     },
#     {
#       "type": "0x2",
#       "chainId": "0x1",
#       "nonce": "0x496",
#       "gas": "0xe83f5",
#       "maxFeePerGas": "0x42c5c115",
#       "maxPriorityFeePerGas": "0x3b9aca00",
#       "to": "0x79cb2970b6c7fc6f22d5dab064c712082213beca

# %% [markdown]
# ### 1-2. Raw Transaction

# %%
tx = block["transactions"][0]
print(json.dumps(tx, indent=2))
# Out:
# {
#   "type": "0x2",
#   "chainId": "0x1",
#   "nonce": "0x3a",
#   "gas": "0x186a0",
#   "maxFeePerGas": "0x136035290",
#   "maxPriorityFeePerGas": "0x1dcd6500",
#   "to": "0x999b49c0d1612e619a4a4f6280733184da025108",
#   "value": "0x0",
#   "accessList": [],
#   "input": "0x095ea7b30000000000000000000000004313c378cc91ea583c91387b9216e2c03096b27f000000000000000000000000000000000000000000000073d4051301d2145ee2",
#   "r": "0xb707fe8e2c84d367b300607118161a55240e2e9b1848e098975c96c1b8b658b",
#   "s": "0x4d03d3523b3decca607e3dc06a64f6122fada92226b613de1a407c70c8cceaf4",
#   "yParity": "0x1",
#   "v": "0x1",
#   "hash": "0xc245864786c73c1f60dff4ac5d1d9bf6eb9504d481798d6010f8f2034a86c797",
#   "blockHash": "0x19930e1087a2a25aeda25e2dfa63335b90d9340b67647805a6b07d3d3cc55d6b",
#   "blockNumber": "0x17e2007",
#   "transactionIndex": "0x0",
#   "from": "0x1da8498facdbb3089197bf12b9f1d24c04c21922",
#   "gasPrice": "0xcd3d8aa3"
# }

# %% [markdown]
# ### 1-3. 100 Blocks

# %%
# Pull 100 blocks, flatten to DataFrame
rows = []
start = latest - 99
for n in range(start, latest + 1):
    b = rpc("eth_getBlockByNumber", [hex(n), True])
    with open(f"../data/raw/block_{n}.json", "w") as f:
        json.dump(b, f)
    ts = int(b["timestamp"], 16)
    for tx in b["transactions"]:
        rows.append({
            "block": n,
            "ts": ts,
            "from": tx["from"],
            "to": tx["to"],
            "value_wei": int(tx["value"], 16),
            "gas": int(tx["gas"], 16),
            "input": tx["input"],
        })
    time.sleep(0.05)
    if n % 10 == 0:
        print(f"pulled block {n}")

df = pd.DataFrame(rows)
df["value_eth"] = df["value_wei"] / 1e18
df["is_contract_call"] = df["input"] != "0x"
print(f"\nTotal txs: {len(df)}")
print(f"Unique senders: {df['from'].nunique()}")
print(f"Contract call ratio: {df['is_contract_call'].mean():.2%}")
df.head()
# Out:
# pulled block 25042860
# pulled block 25042870
# pulled block 25042880
# pulled block 25042890
# pulled block 25042900
# pulled block 25042910
# pulled block 25042920
# pulled block 25042930
# pulled block 25042940
# pulled block 25042950
#
# Total txs: 32808
# Unique senders: 18683
# Contract call ratio: 57.43%
#       block          ts                                        from  \
# 0  25042852  1778153195  0x5875db54cd9ae2b2a875e09bb731772297ae9d92
# 1  25042852  1778153195  0xfd8c07484662cdfa25d8c61190208313f8a84519
# 2  25042852  1778153195  0x7934512c688e6e97b5038c271b47c6d7a0db54c4
# 3  25042852  1778153195  0xae2fc483527b8ef99eb5d9b44875f005ba1fae13
# 4  25042852  1778153195  0x150363ec6dcc84b6c7d6d6283fa3746176f72065
#
#                                            to          value_wei     gas  \
# 0  0x0000000aa232009084bd71a5797d089aa4edfad4                  0  100000
# 1  0x80a64c6d7f12c47b7c66c5b4e20e72bc1fcd5d9e                  0  296679
# 2  0x80a64c6d7f12c47b7c66c5b4e20e72bc1fcd5d9e                  0  296679
# 3  0x1f2f10d1c40777ae1da742455c65828ff36df387           12077291  129317
# 4  0x0000000000001ff3684f28c67538d4d072c22734  10434398622881295  190659
#
#                                                input value_eth  \
# 0  0x1828e0e70000000000000000000000005875db54cd9a...       0.0
# 1  0x3d0e3ec5000000000000000000000000000000000000...       0.0
# 2  0x3d0e3ec5000000000000000000000000000000000000...       0.0
# 3  0x041ea77062de531a98c46ecfb78a5cf7153b5da9527c...       0.0
# 4  0x2213bc0b0000000000000000000000007f54f05635d1...  0.010434
#
#    is_contract_call
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True

# %% [markdown]
# ### 1-4. ERC-20 Transfer Logs from 100 Blocks

# %%
# ERC-20 Transfer logs for 100 blocks
# "0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef"
TRANSFER = Web3.keccak(text="Transfer(address,address,uint256)").hex()
all_logs = []
for start in range(latest-99, latest+1, 10):
    end = min(start+9, latest)
    chunk = rpc("eth_getLogs", [{
        "fromBlock": hex(start),
        "toBlock":   hex(end),
        "topics":    [TRANSFER],
    }])
    all_logs.extend(chunk)
    time.sleep(0.1)

print(json.dumps(all_logs[0], indent=2))
# Out:
# {
#   "address": "0x794269de14d78d5dc4e77da55d69e811054b1110",
#   "topics": [
#     "0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef",
#     "0x000000000000000000000000d9f8bbe437a3423b725c6616c1b543775ecf1110",
#     "0x0000000000000000000000009966880abe51279f66c52e59ac3583c360bf3090"
#   ],
#   "data": "0x000000000000000000000000000000000000000000194512dfee947e840ada4b",
#   "blockHash": "0x1889b3a16166570fe192454fa4f692f0482f6b55ecbf358f17cd0a8c335ad830",
#   "blockNumber": "0x17e1f11",
#   "blockTimestamp": "0x69fc6ffb",
#   "transactionHash": "0x3da8ef5e5458c235925933a613b3c7d8fb1d8385b39f57597a626169a6773fc0",
#   "transactionIndex": "0x0",
#   "logIndex": "0x0",
#   "removed": false
# }
